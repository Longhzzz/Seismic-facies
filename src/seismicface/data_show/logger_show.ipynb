# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif']=['SimHei']   # 用黑体显示中文
plt.rcParams['axes.unicode_minus']=False     # 正常显示负号

# %%
path = '../../../log4/shengli_ngs3/ssl/ts_tcc/cnn1d_encoder/Warp_aug_w8_s-7_attr/logger/logs_18_11_2023_22_36_30.log'
with open(path, 'r') as f:
    logger = f.readlines()

# %%
loss = []
for i in logger[8:]:
    if 'epoch' in i:
        loss.append(eval(i.strip('\n').split(' ')[-1]))

# %%
plt.figure(figsize=(12,6))
plt.plot(loss,'k')
plt.ylabel('loss')
plt.xlabel('epoch')
# Out:
# Text(0.5, 0, 'epoch')
